# %% [markdown]
# <a href="https://colab.research.google.com/github/luisalvarez10/Custom-Mechanical-Keyboards/blob/main/temperaturas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio para convertir temperaturas Celsius a Fahrenheit

# %%
celsius = float(input('Dime la temperatura en ºC: '))
fahrenheit = celsius * (9/5) + 32
kelvin = celsius + 273.15
print('La temperatura de', celsius,'ºC = ',fahrenheit,'ºF')
print('La temperatura de', celsius,'ºC = ',kelvin,'ºK')
# Out:
# Dime la temperatura en ºC: 20
# La temperatura de 20.0 ºC =  68.0 ºF
# La temperatura de 20.0 ºC =  293.15 ºK

# %% [markdown]
# Completa el programa anterior para que también convierta los grados Celsius a grados Kelvin
