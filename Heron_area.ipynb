# %% [markdown]
# <a href="https://colab.research.google.com/github/luisalvarez10/Custom-Mechanical-Keyboards/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int(input("Introduce el tamaño de lado A: "))
ladoB = int(input("Introduce el tamaño de lado B: "))
ladoC = int(input("Introduce el tamaño de lado C: "))

#Cálculo del semiperímetro
s = (ladoA + ladoB + ladoC)/2

#Cálculo del área
area = (s * (s-ladoA) * (s-ladoB) * (s-ladoC)) ** (1/2)

#Imprimimos el resultado
print(f"El área del triángulo es {round(area, 2)}")
# Out:
# Introduce el tamaño de lado A: 4
# Introduce el tamaño de lado B: 4
# Introduce el tamaño de lado C: 5
# 7.81
